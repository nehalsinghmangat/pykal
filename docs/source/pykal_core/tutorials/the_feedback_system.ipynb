# %% [markdown]
# ## The Feedback System

# %% [markdown]
# The [block diagram](https://en.wikipedia.org/wiki/Block_diagram) of a basic [feedback control system](https://en.wikipedia.org/wiki/Control_system#Feedback_control_systems) is shown below.

# %% [markdown]
#    <div style="display: flex; align-items: center; justify-content: space-between; gap: 2em; margin-top: 1em; margin-bottom: 1em;">
#      <img src="../../_static/tikz/tutorial_0/feedback_system.svg" style="width: 100%;">
#    </div>

# %% [markdown]
# There are five distinct blocks, each with a corresponding class representation.
#
# - [Signal Blocks](signal_blocks) (`SignalBlock`)
# - [Function Blocks](function_blocks) (`FunctionBlock`)
# - [Controller Blocks](controller_blocks) (`ControllerBlock`)
# - [Plant Blocks](plant_blocks) (`PlantBlock`)
# - [Observer Blocks](observer_blocks) (`ObserverBlock`)

# %% [markdown]
# The reader may learn about the design and basic usage of a class by clicking on one of the links beneath the block diagram. Alternatively, the reader can follow this tutorial sequentially by following the links below (recommended for new users).

# %% [markdown]
# [<- Overview](overview) | [Tutorials](index) | [Signal Blocks ->](signal_blocks)
