# %% [markdown]
# # Observer Blocks

# %% [markdown]
# ## Defining `ObserverBlock` Objects

# %% [markdown]
# ### Default Attributes

# %% [markdown]
# In ``pykal_core``, we can instantiate one or more independent``ObserverBlock`` objects easily.

# %% [markdown]
# ## Defining `ObserverBlock` Functions

# %% [markdown]
# ### Observer Dynamics

# %% [markdown]
# #### Example: Classic

# %% [markdown]
# #### Example: Kalman Filter

# %% [markdown]
# ### Observer Output

# %% [markdown]
# #### Example: Full State Estimation

# %% [markdown]
# #### Example: Partial State Estimation

# %% [markdown]
# [<- Systems](systems) | [Tutorials](index) | [Detour: Abstract Functions](detour_abstract_functions) | [Controllers ->](controllers)
