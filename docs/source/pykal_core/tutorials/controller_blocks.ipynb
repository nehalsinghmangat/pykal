# %% [markdown]
# # Controller Blocks

# %% [markdown]
# ## Defining `ControllerBlock` Objects

# %% [markdown]
# ### Default Attributes

# %% [markdown]
# In ``pykal_core``, we can instantiate one or more independent``ObserverBlock`` objects easily.

# %% [markdown]
# ## Defining `ControllerBlock` Functions

# %% [markdown]
# ### Controller Dynamics

# %% [markdown]
# #### Example: Gain

# %% [markdown]
# #### Example: Linear-Quadratic Regulator

# %% [markdown]
# ### Observer Output

# %% [markdown]
# #### Example: Full State Control

# %% [markdown]
# #### Example: Partial State Control

# %% [markdown]
# [<- Observers](observers) | [Tutorials](index) |
