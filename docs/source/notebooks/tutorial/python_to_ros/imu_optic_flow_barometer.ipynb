# %% [markdown]
# [← Handling Real Data](../../../getting_started/python_to_ros/handling_real_data.rst)

# %% [markdown]
# # Example: Asynchronous Data via Crazyflie IMU/Optic Flow/Barometer

# %% [markdown]
# [← Handling Real Data](../../../getting_started/python_to_ros/handling_real_data.rst)
